# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x=[1,44,63,31,6,12,-45,-32,-9,-58]
y=[23,45,75,24,-65,-87,23,75,83,5]
plt.plot(x,y, color="purple")

# %%
plt.axis([-50, 0, 0, 100])
plt.xticks((-50,-40,-30,-20,-10,0),('h','e','l','l','o',':)'))
plt.title("Triangle")
plt.xlabel("Array x")
plt.ylabel("Array y")
plt.plot(x,y, color="red")

# %%
plt.hist(x, color="yellow")
plt.hist(y, color="orange")
# Out:
# (array([1., 1., 0., 0., 0., 1., 3., 1., 0., 3.]),
#  array([-87., -70., -53., -36., -19.,  -2.,  15.,  32.,  49.,  66.,  83.]),
#  <a list of 10 Patch objects>)
